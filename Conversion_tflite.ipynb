# %%
import os
os.environ['LD_LIBRARY_PATH'] = '/usr/local/cuda/lib64:' + os.environ.get('LD_LIBRARY_PATH', '')

# %%
import os
print("LD_LIBRARY_PATH:", os.environ.get('LD_LIBRARY_PATH'))
# Out:
# LD_LIBRARY_PATH: /usr/local/cuda/lib64:

# %%
import tensorflow as tf
print("GPUs detected:", tf.config.list_physical_devices('GPU'))
# Out:
# 2025-06-22 19:26:51.386059: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-22 19:26:51.620495: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750638411.701149     837 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750638411.725203     837 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
import tensorflow as tf

model = tf.keras.models.load_model('modelo_hojas_multiclasev3.h5')

converter = tf.lite.TFLiteConverter.from_keras_model(model)

tflite_model = converter.convert()

with open('modelo_hojas_multiclasev3.tflite', 'wb') as f:
    f.write(tflite_model)

print("Modelo convertido a .tflite")
# Out:
# I0000 00:00:1749620003.391017   33451 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5418 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: /tmp/tmpqdpe87f1/assets
# INFO:tensorflow:Assets written to: /tmp/tmpqdpe87f1/assets
# Saved artifact at '/tmp/tmpqdpe87f1'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)
# Captures:
#   133447904846928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447904847312: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ...

# %%
import tensorflow as tf

model = tf.keras.models.load_model('Modelo_2/modelo_plagas_binariov3.h5')

converter = tf.lite.TFLiteConverter.from_keras_model(model)

tflite_model = converter.convert()

with open('modelo_plagas_binario.tflite', 'wb') as f:
    f.write(tflite_model)

print("Modelo convertido a .tflite")
# Out:
# 2025-06-23 18:00:36.088305: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-23 18:00:36.122951: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750719636.146729   73412 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750719636.153968   73412 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
