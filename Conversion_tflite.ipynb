# %%
import os
os.environ['LD_LIBRARY_PATH'] = '/usr/local/cuda/lib64:' + os.environ.get('LD_LIBRARY_PATH', '')

# %%
import os
print("LD_LIBRARY_PATH:", os.environ.get('LD_LIBRARY_PATH'))
# Out:
# LD_LIBRARY_PATH: /usr/local/cuda/lib64:

# %%
import tensorflow as tf
print("GPUs detected:", tf.config.list_physical_devices('GPU'))
# Out:
# 2025-06-11 00:33:12.923274: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-11 00:33:12.955834: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749619992.975775   33451 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749619992.981610   33451 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1749619993.006016   33451 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1749619993.006041   33451 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1749619993.006042   33451 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1749619993.006043   33451 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-06-11 00:33:13.014218: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# GPUs detected: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import tensorflow as tf

model = tf.keras.models.load_model('modelo_hojas_multiclasev3.h5')

converter = tf.lite.TFLiteConverter.from_keras_model(model)

tflite_model = converter.convert()

with open('modelo_hojas_multiclasev3.tflite', 'wb') as f:
    f.write(tflite_model)

print("Modelo convertido a .tflite")
# Out:
# I0000 00:00:1749620003.391017   33451 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5418 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: /tmp/tmpqdpe87f1/assets
# INFO:tensorflow:Assets written to: /tmp/tmpqdpe87f1/assets
# Saved artifact at '/tmp/tmpqdpe87f1'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)
# Captures:
#   133447904846928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447904847312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447904851536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447904850384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447904851152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447904850768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447904853072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447904853264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447904852112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447904846736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447904852880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447904849808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447904853648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447904853840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#
TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901170000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901169424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901169616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901169808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901169040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901170960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901170384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901170576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901170768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901168464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901171920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901171344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901171536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901171728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901169232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901172880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901172304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901172496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901172688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901170192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901173840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901173264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901173456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901173648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901171152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901174800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901174224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901174416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901174608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901172112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901175760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901175184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901175376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901175568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901173072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901176720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901176144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901176336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901176528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901174032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901177680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901177104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901177296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901177488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901174992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901178640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901178064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901178256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901178448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901175952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901179600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901179024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901179216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901179408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901176912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901180560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901179984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901180176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901180368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901177872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901181520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901180944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901181136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901181328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901178832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901182480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901181904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133447901179792: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Modelo convertido a .tflite
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1749620015.208518   33451 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1749620015.208567   33451 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# 2025-06-11 00:33:35.209160: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmpqdpe87f1
# 2025-06-11 00:33:35.216644: I tensorflow/cc/saved_model/reader.cc:52] Reading meta graph with tags { serve }
# 2025-06-11 00:33:35.216662: I tensorflow/cc/saved_model/reader.cc:147] Reading SavedModel debug info (if present) from: /tmp/tmpqdpe87f1
# I0000 00:00:1749620015.301407   33451 mlir_graph_optimization_pass.cc:425] MLIR V1 optimization pass is not enabled
# 2025-06-11 00:33:35.313768: I tensorflow/cc/saved_model/loader.cc:236] Restoring SavedModel bundle.
# 2025-06-11 00:33:35.810745: I tensorflow/cc/saved_model/loader.cc:220] Running initialization op on SavedModel bundle at path: /tmp/tmpqdpe87f1
# 2025-06-11 00:33:35.913133: I tensorflow/cc/saved_model/loader.cc:471] SavedModel load for tags { serve }; Status: success: OK. Took 703978 microseconds.
# 2025-06-11 00:33:36.069739: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.

# %%
import tensorflow as tf

model = tf.keras.models.load_model('modelo_plagas_binariov2.h5')

converter = tf.lite.TFLiteConverter.from_keras_model(model)

tflite_model = converter.convert()

with open('modelo_plagas_binariov2.tflite', 'wb') as f:
    f.write(tflite_model)

print("Modelo convertido a .tflite")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model